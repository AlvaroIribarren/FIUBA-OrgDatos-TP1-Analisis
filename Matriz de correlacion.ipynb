# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df= pd.read_csv('train.csv')

corr = df.corr()

#s = sns.heatmap(corr, cmap="YlGnBu")
#Ver correlacion entre centros comerciales y escuelas 
#Ver como hacer Mapa con cantidad de ventas (geopandas)
