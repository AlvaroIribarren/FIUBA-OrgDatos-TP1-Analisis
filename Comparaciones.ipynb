# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import pandas as pd
path = '/home/andres/Escritorio/OrgaDeDatos'
df= pd.read_csv(path + '/train.csv')

#Fuente: https://es.investing.com/currencies/usd-mxn-historical-data
path1 = '/home/andres/Escritorio/OrgaDeDatos'
dolar= pd.read_csv(path1 + '/Datos históricos USD_MXN.csv')
dolar.columns = ["fecha", "last", "opening", "max", "min", "std"]
dolar.drop(["std", "opening", "opening", "max", "min"], axis=1 ,inplace=True)


dolar['date'] = pd.to_datetime(dolar['fecha'], format="%b %Y")
dolar.drop(["fecha"], axis=1, inplace=True)


dolar.columns= ['price', "date"]

dolar['price'] = dolar['price'].replace(',', '.', regex=True).astype(float)
dolar["year"] = dolar.date.dt.year
dolar['month'] = dolar.date.dt.month
dolar.drop(["date"], axis=1, inplace=True)


df['fecha'] = pd.to_datetime(df['fecha'])
df['year'] = df['fecha'].dt.year
df['month']= df['fecha'].dt.month

sns.set_context("paper", font_scale=1.9) 
newDf= pd.merge(df, dolar, on=['year', 'month'], how='left')
newDf["dollar_price"] = newDf.apply(lambda row: row["precio"]/row["price"], axis=1)
newDf.antiguedad.astype
# Out:
# <bound method NDFrame.astype of 0          NaN
# 1         10.0
# 2          5.0
# 3          1.0
# 4         10.0
# 5          5.0
# 6          NaN
# 7          2.0
# 8          1.0
# 9          NaN
# 10         0.0
# 11         NaN
# 12         0.0
# 13        20.0
# 14         NaN
# 15         NaN
# 16         0.0
# 17         5.0
# 18         NaN
# 19         0.0
# 20         0.0
# 21         NaN
# 22         0.0
# 23         4.0
# 24         4.0
# 25         8.0
# 26         3.0
# 27        18.0
# 28         1.0
# 29        20.0
#           ...
# 239970    10.0
# 239971     4.0
# 239972    20.0
# 239973     1.0
# 239974     4.0
# 239975     NaN
# 239976     NaN
# 239977     5.0
# 239978     NaN
# 239979    10.0
# 239980     1.0
# 239981    10.0
# 239982     NaN
# 239983     NaN
# 239984    20.0
# 239985    10.0
# 239986     0.0
# 239987     0.0
# 239988     5.0
# 239989     2.0
# 239990    20.0
# 239991    20.0
# 239992    10.0
# 239993     1.0
# 239994     3.0
# 239995     0.0
# ...

# %%
dg = newDf.groupby('antiguedad').agg({'precio':'mean'})
dg.reset_index(inplace=True)

dh=dg.iloc[0:10].mean()
dh['01 / 10 Años'] = dh['precio']
dh.drop('antiguedad',inplace=True)
dh.drop('precio',inplace=True)
dh.to_frame()


dh2=dg.iloc[10:20].mean()
dh2['10 / 20 Años'] = dh2['precio']
dh2.drop('antiguedad',inplace=True)
dh2.drop('precio',inplace=True)
dh2.to_frame()

dh3=dg.iloc[20:30].mean()
dh3['20 / 30 Años'] = dh3['precio']
dh3.drop('antiguedad',inplace=True)
dh3.drop('precio',inplace=True)
dh3.to_frame()


dh4=dg.iloc[30:40].mean()
dh4['30 / 40 Años'] = dh4['precio']
dh4.drop('antiguedad',inplace=True)
dh4.drop('precio',inplace=True)
dh4.to_frame()


dh5=dg.iloc[40:50].mean()
dh5['40 / 50 Años'] = dh5['precio']
dh5.drop('antiguedad',inplace=True)
dh5.drop('precio',inplace=True)
dh5.to_frame()


dh8=dg.iloc[50:60].mean()
dh8['50 / 60 Años'] = dh8['precio']
dh8.drop('antiguedad',inplace=True)
dh8.drop('precio',inplace=True)
dh8.to_frame()


dh6=dg.iloc[60:70].mean()
dh6['60 / 70 Años'] = dh6['precio']
dh6.drop('antiguedad',inplace=True)
dh6.drop('precio',inplace=True)
dh6.to_frame()


dh7=dg.iloc[70:80].mean()
dh7['70 / 80 Años'] = dh7['precio']
dh7.drop('antiguedad',inplace=True)
dh7.drop('precio',inplace=True)
dh7.to_frame()



frames = [dh, dh2, dh3,dh4,dh5,dh6,dh7,dh8]

result = pd.concat(frames)

apa = result.to_frame()
apa.reset_index(inplace=True)
apa.columns = ['Antiguedad','Precio']


apa.sort_values(by=['Precio'],ascending = [True],inplace = True)
sns.set(style="darkgrid")
sns.set_context("paper", font_scale=5.9)
sns.catplot(x="Antiguedad",y='Precio',kind='point',data=apa,height=14,aspect=3.6)

# %%
dg = newDf.groupby('antiguedad').agg({'dollar_price':'mean'})
dg.reset_index(inplace=True)

dh=dg.iloc[0:10].mean()
dh['01 / 10 Años'] = dh['dollar_price']
dh.drop('antiguedad',inplace=True)
dh.drop('dollar_price',inplace=True)
dh.to_frame()


dh2=dg.iloc[10:20].mean()
dh2['10 / 20 Años'] = dh2['dollar_price']
dh2.drop('antiguedad',inplace=True)
dh2.drop('dollar_price',inplace=True)
dh2.to_frame()

dh3=dg.iloc[20:30].mean()
dh3['20 / 30 Años'] = dh3['dollar_price']
dh3.drop('antiguedad',inplace=True)
dh3.drop('dollar_price',inplace=True)
dh3.to_frame()


dh4=dg.iloc[30:40].mean()
dh4['30 / 40 Años'] = dh4['dollar_price']
dh4.drop('antiguedad',inplace=True)
dh4.drop('dollar_price',inplace=True)
dh4.to_frame()


dh5=dg.iloc[40:50].mean()
dh5['40 / 50 Años'] = dh5['dollar_price']
dh5.drop('antiguedad',inplace=True)
dh5.drop('dollar_price',inplace=True)
dh5.to_frame()


dh8=dg.iloc[50:60].mean()
dh8['50 / 60 Años'] = dh8['dollar_price']
dh8.drop('antiguedad',inplace=True)
dh8.drop('dollar_price',inplace=True)
dh8.to_frame()


dh6=dg.iloc[60:70].mean()
dh6['60 / 70 Años'] = dh6['dollar_price']
dh6.drop('antiguedad',inplace=True)
dh6.drop('dollar_price',inplace=True)
dh6.to_frame()


dh7=dg.iloc[70:80].mean()
dh7['70 / 80 Años'] = dh7['dollar_price']
dh7.drop('antiguedad',inplace=True)
dh7.drop('dollar_price',inplace=True)
dh7.to_frame()



frames = [dh, dh2, dh3,dh4,dh5,dh6,dh7,dh8]

result = pd.concat(frames)

apa = result.to_frame()
apa.reset_index(inplace=True)
apa.columns = ['Antiguedad','Precio en Dolares']


apa.sort_values(by=['Precio en Dolares'],ascending = [True],inplace = True)
sns.set(style="darkgrid")
sns.set_context("paper", font_scale=5.9)
sns.catplot(x="Antiguedad",y='Precio en Dolares',kind='point',data=apa,height=14,aspect=3.6)

# %%
filtro = newDf['provincia'].isin(['Distrito Federal','Veracruz','Puebla'])
df=newDf[filtro]
dfx = df.groupby(['year','provincia']).agg({'dollar_price':'mean'})
dfx.reset_index(inplace=True)
dfa = df.groupby(['year','provincia']).agg({'precio':'mean'})
dfa.reset_index(inplace=True)
g0 = sns.relplot(x="year",y='dollar_price',kind='line',data=dfx,hue='provincia',aspect=1.5)
g1=sns.relplot(x="year",y='precio',kind='line',data=dfa,hue='provincia',aspect=1.5)
g1.set_axis_labels( "Año","Precio en moneda mexicana")
g0.set_axis_labels( "Año","Precio en dolares")
###PRECIO DEL DOLAR POR PROVINCIA/ANIOS.

# %%
sns.set_context("paper", font_scale=1.9) 
filtro1 = newDf['year'].isin(['2015'])
filtro = newDf['habitaciones'].isin(['1.0'])
filtro2 = newDf['piscina'].isin(['0.0'])
filtro3 = newDf['escuelascercanas'].isin(['0.0'])
filtro4 = newDf['usosmultiples'].isin(['0.0'])
filtro5 = newDf['tipodepropiedad'].isin(['Rancho'])

#da=newDf[filtro3&filtro4]
dfx = newDf.groupby(['habitaciones']).agg({'precio':'mean'})
dfx.sort_values(by=['precio'],ascending = [False],inplace = True)
dfx.reset_index(inplace=True)



g0 = sns.relplot(x="habitaciones",y='precio',kind='line',data=dfx,aspect=2,palette='rainbow')

# %%
sns.set_context("paper", font_scale=1.9) 
filtro1 = newDf['year'].isin(['2015'])
filtro = newDf['habitaciones'].isin(['1.0'])
filtro2 = newDf['piscina'].isin(['0.0'])
filtro3 = newDf['escuelascercanas'].isin(['0.0'])
filtro4 = newDf['usosmultiples'].isin(['0.0'])
filtro5 = newDf['tipodepropiedad'].isin(['Rancho'])

#da=newDf[filtro3&filtro4]
dfx = newDf.groupby(['habitaciones','year']).agg({'precio':'mean'})
dfx.sort_values(by=['precio'],ascending = [False],inplace = True)
dfx.reset_index(inplace=True)



g0 = sns.relplot(x="habitaciones",y='precio',kind='line',data=dfx,hue='year',col_wrap=3,col='year'
                ,palette='rainbow')

# %%
sns.set_context("paper", font_scale=1.9) 
filtro1 = newDf['year'].isin(['2015'])
filtro = newDf['habitaciones'].isin(['1.0'])
filtro2 = newDf['piscina'].isin(['0.0'])
filtro3 = newDf['escuelascercanas'].isin(['0.0'])
filtro4 = newDf['usosmultiples'].isin(['0.0'])
filtro5 = newDf['tipodepropiedad'].isin(['Rancho'])

#da=newDf[filtro3&filtro4]



g0 = sns.catplot(x="garages",y='precio',kind='point',data=newDf)

# %%
sns.set_context("paper", font_scale=1.9) 
filtro1 = newDf['year'].isin(['2015'])
filtro = newDf['habitaciones'].isin(['1.0'])
filtro2 = newDf['piscina'].isin(['0.0'])
filtro3 = newDf['escuelascercanas'].isin(['0.0'])
filtro4 = newDf['usosmultiples'].isin(['0.0'])
filtro5 = newDf['tipodepropiedad'].isin(['Rancho'])

#da=newDf[filtro3&filtro4]
dfx = newDf.groupby(['garages','year']).agg({'precio':'mean'})
dfx.sort_values(by=['precio'],ascending = [False],inplace = True)
dfx.reset_index(inplace=True)



g0 = sns.relplot(x="garages",y='precio',kind='line',data=dfx,hue='year',col_wrap=3,col='year'
                ,palette='rainbow')

# %%
sns.set_context("paper", font_scale=4.9) 
filtro1 = newDf['year'].isin(['2012'])
filtro4 = newDf['provincia'].isin(['Distrito Federal'])
filtro5 = newDf['tipodepropiedad'].isin(['Casa'])
dfx=newDf[filtro1&filtro4&filtro5]
dfx = dfx.groupby(['antiguedad']).agg({'precio':'mean'})
dfx.sort_values(by=['precio'],ascending = [False],inplace = True)
dfx.reset_index(inplace=True)



g0 = sns.catplot(y="antiguedad",x='precio',kind='point',data=dfx,height=42,aspect=1.3,orient='h')

# %%
sns.set_context("paper", font_scale=1.9)

filtro1 = newDf['gimnasio'].isin(['0.0'])
filtro2 = newDf['piscina'].isin(['0.0'])
filtro3 = newDf['escuelascercanas'].isin(['0.0'])
filtro4 = newDf['usosmultiples'].isin(['0.0'])
filtro5 = newDf['tipodepropiedad'].isin(['Casa','Apartamento'])

filtro6 = newDf['gimnasio'].isin(['1.0'])
filtro7 = newDf['piscina'].isin(['1.0'])
filtro8 = newDf['escuelascercanas'].isin(['1.0'])
filtro9 = newDf['usosmultiples'].isin(['1.0'])
filtro0 = newDf['tipodepropiedad'].isin(['Casa','Apartamento'])

d0=newDf[filtro1&filtro2&filtro3&filtro4&filtro5]
d1=newDf[filtro6&filtro7&filtro8&filtro9&filtro0]

d0.groupby('year').agg({'precio':'mean'})
d1.groupby('year').agg({'precio':'mean'})



g1 = sns.catplot(x="year",y='precio',kind='bar',data=d1,hue='tipodepropiedad',aspect=1.7)

g0 = sns.catplot(x="year",y='precio',kind='bar',data=d0,hue='tipodepropiedad',aspect=1.7)


g1.set_axis_labels("Años", "Precio con lujos")
g0.set_axis_labels("Años", "Precio sin lujos")
