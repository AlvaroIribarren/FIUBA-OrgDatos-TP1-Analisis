# %%
import pandas as pd

path = '/home/handerllon/Desktop/OrgaDeDatos/TP1'
df = pd.read_csv (path + '/train.csv',)
#df.loc[(df.ciudad == "La Magdalena Contreras")]
#df.loc[df.antiguedad.notna()].shape
#print((44/250)*100)

# generamos nuevas columnas seteando el tipo datetime
df['fecha'] = pd.to_datetime(df['fecha'])
# generamos una nueva columna obteniendo el año, esto los usuaremos en visualizacion.
#projects_2017['year'] = projects_2017['launched_datetime'].dt.year

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240000 entries, 0 to 239999
# Data columns (total 23 columns):
# id                            240000 non-null int64
# titulo                        234613 non-null object
# descripcion                   238381 non-null object
# tipodepropiedad               239954 non-null object
# direccion                     186928 non-null object
# ciudad                        239628 non-null object
# provincia                     239845 non-null object
# antiguedad                    196445 non-null float64
# habitaciones                  217529 non-null float64
# garages                       202235 non-null float64
# banos                         213779 non-null float64
# metroscubiertos               222600 non-null float64
# metrostotales                 188533 non-null float64
# idzona                        211379 non-null float64
# lat                           116512 non-null float64
# ...

# %%
display(df)
# Out:
#             id                                             titulo  \
# 0       254099                                  depto. tipo a-402
# 1        53461                     condominio horizontal en venta
# 2       247984              casa en venta urbi 3 recamaras tonala
# 3       209067  casa sola en toluca zinacantepec con credito i...
# 4       185997                                     paseos del sol
# 5       126147                     departamento en venta taxqueña
# 6       139233                 de oportunidad casa en san lorenzo
# 7         5013  casa emilia en venta en selvamar playa del carmen
# 8        44962  pre- venta preciosos depas 2 recamaras con sub...
# 9       134537                                            terreno
# 10       51180                                      mi 2° credito
# 11      103293  departamento en venta, san pedro garza garcia,...
# 12       47890             hermosa casa en zibata queretaro 170m²
# ...

# %%
df.isnull().any()
# Out:
# id                            False
# titulo                         True
# descripcion                    True
# tipodepropiedad                True
# direccion                      True
# ciudad                         True
# provincia                      True
# antiguedad                     True
# habitaciones                   True
# garages                        True
# banos                          True
# metroscubiertos                True
# metrostotales                  True
# idzona                         True
# lat                            True
# lng                            True
# fecha                         False
# gimnasio                      False
# usosmultiples                 False
# piscina                       False
# escuelascercanas              False
# centroscomercialescercanos    False
# precio                        False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# id                                 0
# titulo                          5387
# descripcion                     1619
# tipodepropiedad                   46
# direccion                      53072
# ciudad                           372
# provincia                        155
# antiguedad                     43555
# habitaciones                   22471
# garages                        37765
# banos                          26221
# metroscubiertos                17400
# metrostotales                  51467
# idzona                         28621
# lat                           123488
# lng                           123488
# fecha                              0
# gimnasio                           0
# usosmultiples                      0
# piscina                            0
# escuelascercanas                   0
# centroscomercialescercanos         0
# precio                             0
# dtype: int64

# %%
df.describe()
# Out:
#                   id     antiguedad   habitaciones        garages  \
# count  240000.000000  196445.000000  217529.000000  202235.000000
# mean   149969.382092       8.116114       2.902326       1.546874
# std     86634.579744       9.553830       0.896894       0.853507
# min         1.000000       0.000000       1.000000       0.000000
# 25%     74930.750000       0.000000       2.000000       1.000000
# 50%    149875.500000       5.000000       3.000000       2.000000
# 75%    225016.500000      10.000000       3.000000       2.000000
# max    299999.000000      80.000000      10.000000       3.000000
#
#                banos  metroscubiertos  metrostotales        idzona  \
# count  213779.000000    222600.000000  188533.000000  2.113790e+05
# mean        2.132417       174.016774     176.765145  2.423468e+06
# std         0.912546        98.152950      94.427328  1.056794e+07
# min         1.000000        15.000000      15.000000  2.200000e+01
# ...

# %%
df.loc[df.antiguedad.isnull()]
# Out:
#             id                                             titulo  \
# 0       254099                                  depto. tipo a-402
# 6       139233                 de oportunidad casa en san lorenzo
# 9       134537                                            terreno
# 11      103293  departamento en venta, san pedro garza garcia,...
# 14      181436                        casa en venta en valle real
# 15      201923               casa en venta lomas verdes naucalpan
# 18       40421  últimos terrenos en preventa!! en bukara coto ...
# 21      224513                         casa en venta en querétaro
# 32      261416           casa en venta en montebello, merida - pf
# 36      261703  hermosa casa en desarrollo en juriquilla (quer...
# 37        1127  casa en venta en tampico zona centro calle dr....
# 40       82384             fraccionamiento libélulas modelo lírio
# 57      241431              terreno en residencial la vista 323m2
# ...

# %%
gk = df.groupby(['tipodepropiedad', 'ciudad'])
gk.first()
# Out:
#                                            id  \
# tipodepropiedad ciudad
# Apartamento     Acajete                296397
#                 Acambay                131424
#                 Acapulco de Juárez     224685
#                 Acateno                194815
#                 Acatzingo              236582
#                 Acolman                128115
#                 Actopan                102017
#                 Aguascalientes           1741
#                 Ahome                   51008
#                 Altamira               169310
#                 Alvarado                93814
#                 Alvaro Obregón         171944
#                 Amealco de Bonfil      271432
#                 Amozoc                 237351
#                 Apaseo el Grande       273160
#                 Apizaco                 68355
#                 Apodaca                 86874
#                 Atempan                215051
#                 Atizapán               254403
# ...

# %%
gx = df.sort_values(by=['precio','metroscubiertos']).head()
gx = gx[['precio', 'metroscubiertos']].copy()
display(gx)
# Out:
#           precio  metroscubiertos
# 23537   310000.0             29.0
# 62824   310000.0             30.0
# 100685  310000.0             30.0
# 197218  310000.0             32.0
# 86060   310000.0             33.0

# %%
df6 = df.groupby(['tipodepropiedad','ciudad'])
df6.count().head(100)
# Out:
#                                         id  titulo  descripcion  direccion  \
# tipodepropiedad ciudad
# Apartamento     Acajete                  1       1            1          0
#                 Acambay                  1       1            1          1
#                 Acapulco de Juárez    1498    1395         1483       1287
#                 Acateno                  1       1            1          0
#                 Acatzingo                1       1            1          0
#                 Acolman                  5       5            5          5
#                 Actopan                  1       1            1          1
#                 Aguascalientes          46      46           46         41
#                 Ahome                    2       2            2          1
#                 Altamira                20      19           20         10
#                 Alvarado                38      38           38         18
# ...
